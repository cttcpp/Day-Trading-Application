# %%
from googlefinance import getQuotes, getNews
from sys import stdout
import pandas as pd
import numpy as np
import datetime
import urllib
import time
import pickle

print "Done"
# Out:
# Done

# %%
def company_news(newstickers):
    tickernewslist = {}
    
    for each in newstickers:
        tickernewslist[each] = getNews(each)  
    return tickernewslist

def stock_splits(stock_split_dates):
    splitup        = urllib.urlopen(stock_split_dates).read()
    companies      = splitup.find('Announced')
    stop           = splitup.find('th_No_BG', companies)
    company_splits = []
    
    while True:
        done      = splitup.find(')</a>',stop)+1
        next_stop = splitup.rfind('(', stop, done)
        ratio_s   = splitup.find('<td>',done)+4
        ratio_e   = splitup.find('<',ratio_s)
        payment_e = splitup.find('2016',done)+4
        payment_s = splitup.rfind('<td>',stop,payment_e)+4
        exdate_s  = splitup.find('<td>',payment_e)+4
        exdate_e  = splitup.find('</td>',exdate_s)
        
        company_splits.append([splitup[next_stop+1:done-1],
                               splitup[exdate_s:exdate_e],
                               splitup[ratio_s:ratio_e],
                               splitup[payment_s:payment_e]])
        
        tbody = splitup.find('</table>',done)
        test  = splitup.find('(',done)
        
        if tbody < test:
            break
        stop = done
    return company_splits

def dividend_find(dividend_dates): 
    company_dividends = []
    for x in xrange(0,2):
        if x != 0:
            dividends      = urllib.urlopen(dividend_dates).read()  
            end            = dividends.find('Next')-2
            start          = dividends.rfind('href=',0,end)+6
            next_day       = dividends[start:end]
            dividend_dates = 'http://www.nasdaq.com/dividend-stocks/'+next_day 
            
        dividends = urllib.urlopen(dividend_dates).read()  
        start     = dividends.find('Payment Date')
        
        while True:
            start      = dividends.find('&#40;',start)+5
            end        = dividends.find('&#41;',start)
            ex_date_e  = dividends.find('2016',end)+4
            ex_date_s  = dividends.rfind('>',end,ex_date_e)+1
            div_e      = dividends.find('</',ex_date_e+1)
            div_s      = dividends.rfind('>',ex_date_e,div_e)+1
            rec_date_e = dividends.find('2016',div_e)+4
            rec_date_s = dividends.rfind('>',div_e,rec_date_e)+1
            proceed    = dividends.find('2016',rec_date_e)+4
            pay_date_e = dividends.find('2016',proceed)+4
            pay_date_s = dividends.rfind('>',proceed,pay_date_e)+1
            
            company_dividends.append([dividends[start:end],
                                    dividends[ex_date_s:ex_date_e],
                                    dividends[div_s:div_e],
                                    dividends[rec_date_s:rec_date_e],
                                    dividends[pay_date_s:pay_date_e]])
            
            test = dividends.find('&#40;',start)
            if test == -1:
                break
            start = end      
    return company_dividends

def yahoo_backup():
    test_array = []
    yahoo      = 'http://finance.yahoo.com/q?s='
    tickers    = ['LGF', 'AMAG', 'CYH', 'HA', 'HPQ', 'ENDP', 'VRX', 
                  'SVU', 'FBR', 'IMGN', 'UIS', 'NSM', 'YRCW', 'BZH', 
                  'SWN', 'ATW', 'EXAS', 'TK', 'PBR', 'ITUB', 'LSCC', 
                  'MBI', 'SBS', 'AG', 'STLD', 'ATSG', 'HR', 'WTW', 
                  'GGAL', 'NJR', 'ITG', 'AEIS', 'NEM', 'ANF', 'INT', 
                  'COH', 'TREX', 'CSH', 'NTGR', 'BRKR', 'EDE', 'CCOI', 
                  'HRL', 'AEM', 'GVA', 'NVDA', 'CBT', 'CSGS',
                  '%5EIXIC','%5EDJI','^RUT','^GSPC','^NYA']
    
    for each in tickers:
        stock       = yahoo + each
        page        = urllib.urlopen(stock).read()
        price       = page.find('time_rtq_ticker')
        price_stop  = page.find('</span>',price)
        price_start = page.rfind('>',price_stop-10,price_stop)+1
        
        test_array.append(page[price_start:price_stop])
    return test_array

print "Done"
# Out:
# Done

# %%
def total_stock_movements(new_codes):
    i, y, new_new = 0, 0, []

    for each in new_codes:
        if ' ' not in each:
            new_new.append(each)
            
    for x in xrange(0,6365,95):
        if x != 6270:
            new_test = new_new[x:x+95]
        else:
            new_test = new_new[x:]
        
        try:
            test = getQuotes(new_test)
        except:
            return "FAIL"
            pass
        
        for each in test:
            if each['ChangePercent'] != '':
                if each['ChangePercent'][0] == '+':
                    i += 1
                if each['ChangePercent'][0] == '-':
                    y += 1
    
    movement = i - y
    return movement

def real_time_quotes(tickers, new_codes, closings, outlist, yesterday):
    tickerlist  = [[] for i in range(53)]
    dailylist   = [[] for i in range(53)]
    first_close = [[] for i in range(53)]
    last_close  = [[] for i in range(53)]
    mylist      = [[] for i in range(53)]
    daily       = [[] for i in range(53)]

    start, new_array, market_movement = True, [],  []
    seconds, minutes, hours, i, z  = 60, 60, 7, 0, True
    
    t_end = time.time() + seconds * minutes * hours
    
    while time.time() < t_end:
        try:
            next_quotes = getQuotes(tickers)          
            for x in xrange(0,len(next_quotes)):
                tickerlist[x].append(next_quotes[x])
                
                if start == True:
                    first_close[x] = float(next_quotes[x]['LastTradePrice'].replace(',',''))
                    seconds_return = 0.0
                else:
                    last_close[x]  = float(next_quotes[x]['LastTradePrice'].replace(',',''))
                    seconds_return = last_close[x] / first_close[x] - 1.
                    first_close[x] = last_close[x] 
                    
                dailylist[x].append(seconds_return)
                
            if (i % 30) == 0 or i == 1:
                movement = total_stock_movements(new_codes)
                market_movement.append(movement)
                stdout.write("\r%d" % i)
                stdout.flush()
            else:
                stdout.write("\r%d" % i)
                stdout.flush()
                time.sleep(10)
                
            if i > 0:
                combined, z, mylist = calculate_attributes(closings, tickers, last_close, market_movement, mylist, z)    
                for u in xrange(0,len(tickerlist)):
                    if len(tickerlist[u]) <= len(yesterday[u]):
                        daily[u].append((float(tickerlist[u][i]['LastTradePrice'].replace(',','')) / 
                                         float(yesterday[u][i]['LastTradePrice'].replace(',',''))) - 1)
                    else:
                        break
                
            i          += 1
            start       = False 
        
        except:
            next_quotes = yahoo_backup()
            for x in xrange(0,len(next_quotes)):
                tickerlist[x].append(next_quotes[x])
                
                if i == 0:
                    first_close[x] = float(next_quotes[x].replace(',',''))
                    seconds_return = 0.0
                else:
                    last_close[x]  = float(next_quotes[x].replace(',',''))
                    seconds_return = last_close[x] / first_close[x] - 1.
                    first_close[x] = last_close[x]
                    
                dailylist[x].append(seconds_return)
                
            print "PRIMARY FAIL", i
            i += 1
            pass
            
    closings,company_features = day_end_operations(tickers, tickerlist, closings) 
    return tickerlist, dailylist, market_movement, closings, combined, daily, company_features

def calculate_attributes(closings, tickers, last_close, market_movement, mylist, z):
    if z == True:
        mylist = make_year_list(closings,tickers,mylist)

    company_combined = [[] for i in range(53)]
    for x in xrange(0,48):
        mylist[x].loc[252] = last_close[x]
        sma                = mylist[x].rolling(window=50,center=False).mean()
        rm                 = mylist[x].rolling(window=20,center=False).mean()
        rstd               = mylist[x].rolling(window=20,center=False).std()
        upper_band         = rm + rstd * 2
        lower_band         = rm - rstd * 2
    
        boll       = (mylist[x].loc[252,0] - rm.loc[252,0]) / (upper_band.loc[252,0] - rm.loc[252,0])
        sma        =  sma.loc[252,0]
        mom        = (mylist[x].loc[252,0] /  mylist[x].loc[242,0])-1
        pe         =  mylist[x].loc[252,0] / (mylist[x].loc[252,0] - mylist[x].loc[0,0])
        combined   = [boll,sma,mom,pe,market_movement[-1]]
            
        for y in xrange(48,len(mylist)):
            combined.append(last_close[y] / mylist[y].loc[251,0]-1)   
        company_combined[x] = combined
            
    z = False
    return company_combined, z, mylist

def make_year_list(closings, tickers, mylist):
    y = 0

    for each in tickers:
        df        = closings[each][len(closings[each])-252:len(closings[each])]
        mylist[y] = pd.DataFrame(df[0].values.tolist())
        y        += 1  
    return mylist

def day_end_operations(tickers, tickerlist, closings, market_movement):
    i = 0  
    combined = {}
    for each in tickers:
        try:
            num                = float(tickerlist[i][-1]['LastTradePrice'].replace(',',''))
            date               = datetime.date.today()
            test               = pd.DataFrame([num], index=[date])
            closings[each]     = closings[each].append(test)  
            
            rm                 = closings[each].rolling(window=20,center=False).mean()
            rstd               = closings[each].rolling(window=20,center=False).std()
            upper_band         = rm + rstd * 2
            lower_band         = rm - rstd * 2

            sma                = closings[each].rolling(window=50,center=False).mean()
            boll               = (closings[each] - rm) / (upper_band - rm)
            mom                = (closings[each] /  closings[each].shift(10))-1
            pe                 =  closings[each] / (closings[each] - closings[each].shift(252))
            daily_returns      = (closings[each] / closings[each].shift(1)) - 1
              
            boll               = boll.replace([np.inf, -np.inf], 0)
            mom                = mom.replace([np.inf, -np.inf], 0)
            pe                 = pe.replace([np.inf, -np.inf], 0)
            daily_returns      = daily_returns.replace([np.inf, -np.inf], 0)
            
            combined[each]     = [boll,sma,mom,pe,daily_returns]
            
        except:
            print each
            pass       
        i += 1  
        
    cl2 = open('smallcompanyclosingslist.pickle','wb')
    cl3 = open('smallcompanyfeatureslist.pickle','wb')
    pickle.dump(closings,cl2)
    pickle.dump(combined,cl3)
    cl2.close()
    cl3.close()
    return closings, combined

print "Done"
# Out:
# Done

# %%
def get_data_ready():
    cl = open('smallcompanyclosingslist.pickle','rb')
    ye = open('05272016dayendtickerlist.pickle','rb')
    closings = pickle.load(cl)
    yesterday = pickle.load(ye)
    cl.close()
    ye.close()
    
    tickers = ['LGF', 'AMAG', 'CYH', 'HA', 'HPQ', 'ENDP', 'VRX', 
                'SVU', 'FBR', 'IMGN', 'UIS', 'NSM', 'YRCW', 'BZH', 
                'SWN', 'ATW', 'EXAS', 'TK', 'PBR', 'ITUB', 'LSCC', 
                'MBI', 'SBS', 'AG', 'STLD', 'ATSG', 'HR', 'WTW', 
                'GGAL', 'NJR', 'ITG', 'AEIS', 'NEM', 'ANF', 'INT', 
                'COH', 'TREX', 'CSH', 'NTGR', 'BRKR', 'EDE', 'CCOI', 
                'HRL', 'AEM', 'GVA', 'NVDA', 'CBT', 'CSGS',
                'INDEXNASDAQ:.IXIC','INDEXDJX:.DJI','RUT','INDEXSP:.INX','INDEXNYSEGIS:NYA']
    
    stock_split_dates    = 'http://www.nasdaq.com/markets/upcoming-splits.aspx'
    dividend_dates       = 'http://www.nasdaq.com/dividend-stocks/dividend-calendar.aspx'
    today_next_dividends = pd.DataFrame(dividend_find(dividend_dates),   columns=['Symbol','ExDiv','Div','RecDate','PayDate'])
    upcoming_splits      = pd.DataFrame(stock_splits(stock_split_dates), columns=['Symbol','ExDate','Ratio','Payable'])   
    divs                 = today_next_dividends['Symbol'].values
    splits               = upcoming_splits['Symbol'].values
    outlist              = []
    
    for each in divs:
        if each in tickers:
            print each, "DIV"
            
    for each2 in splits:
        if each2 in tickers:
            print each2, "SPLITS"
            outlist.append(each2)
            
    todays_news  = company_news(tickers)
    new_codes    = pd.read_csv("C:/Users/JohnSmith2/Downloads/nasdaq.csv",usecols=['Symbol'])
    new_codes2   = pd.read_csv("C:/Users/JohnSmith2/Downloads/nyse.csv",usecols=['Symbol'])
    new_codes    = new_codes.append(new_codes2, ignore_index=True)
    new_codes    = np.array(new_codes['Symbol'].values)
    
    tn = open('05302016companynews.pickle','wb')
    pickle.dump(todays_news,tn)
    tn.close()
    
    return tickers, new_codes, closings, outlist, yesterday, todays_news


time.sleep(25800)
tickers, new_codes, closings, outlist, yesterday, todays_news = get_data_ready()
tickerlist, dailylist, market_movement, closings, combined, daily, company_features = \
    real_time_quotes(tickers, new_codes, closings, outlist, yesterday)

print "Done"
# Out:
# Done

# %%
#Aroon Index
period = 25
new_closing = closings[each][len(closings[each][0]) - (period+1):len(closings[each][0])]
aroon_up   = ((25 - (25 - new_closing[0].idxmax())) / 25) * 100
aroon_down = ((25 - (25 - new_closing[0].idxmax())) / 25) * 100

#Volatility Index
voli_per = 30
voli_closing = closings[each][len(closings[each][0]) - voli_period:len(closings[each][0])]
voli_closing_list = voli_closing[0].values.tolist()
mean = voli_closing.mean()
total = 0
for each in voli_closing_list:
    sqr_dev = (each - mean)**2
    total = total + sqr_dev
volatility = total / voli_per

#On-Board Volume
for i in xrange(0,len(closingvolume[each]):
    if i == 0:
        previous_obv = current_vol
    else:
        current = closingvolume[each].iloc[i]
        previous = closingvolume[each].iloc[i-1]
        if current['close'] != previous['close']:
            if current['Close'] > previous['Close']:
                obv = previous_obv + current['Volume']
                previous_obv = obv
            else:
                obv = previous_obv - current['Volume']
                previous_obv = obv

#Accumulation/Distribution Line
for i in xrange(0,len(highlowclosedf[each])):
    highlowclose          = highlowclosedf[each].iloc[i]
    money_flow_multiplier = (((highlowclose['close'] - highlowclose['low']) - 
                              (highlowclose['high']  - highlowclose['close'])) / 
                              (highlowclose['high']  - highlowclose['low']))
    money_flow_volume     = money_flow_multiplier * highlowclose['volume']
    
    if i == 0:
        previous_adl = money_flow_volume
    else:
        adl = previous_adl + money_flow_volume
        previous_adl = adl
   
#Money Flow Index   
positive_money_flow, negative_money_flow = 0, 0
for i in xrange(0,len(highlowclosedf[each])):          
    if i == 0:
        highlowclose           = highlowclosedf[each].iloc[i]  
        previous_typical_price = (highlowclose['high'] + highlowclose['low'] + highlowclose['close']) / 3
    else:
        highlowclose           = highlowclosedf[each].iloc[i]
        prevhighlowclose       = highlowclosedf[each].iloc[i-1]
        typical_price          = (highlowclose['high'] + highlowclose['low'] + highlowclose['close']) / 3
        previous_typical_price = (prevhighlowclose['high'] + prevhighlowclose['low'] + prevhighlowclose['close']) / 3
        money_flow             = typical_price * highlowclose['volume']

        if typical_price != previous_typical_price:
            if typical_price > previous_typical_price:
                positive_money_flow = positive_money_flow + money_flow
            else:
                negative_money_flow = negative_money_flow + money_flow

        money_ratio      = positive_money_flow / negative_money_flow
        money_flow_index = 100 - (100 / (1 + money_ratio))

#Volume Weighted Moving Average
cum_flow, cum_vol = 0, 0          
for i in xrange(0,len(highlowclosedf[each])):
    highlowclose = highlowclosedf[each].iloc[i]
    typical_price = (highlowclose['high'] + highlowclose['low'] + highlowclose['close']) / 3
    money_flow = typical_price * highlowclose['volume']
    cum_flow = cum_flow + money_flow
    cum_vol = cum_vol + highlowclose['volume']       
    vwma = cum_flow / cum_vol
    
#Average Directional Index
true_range, plus_DM, minus_DM = [], [], []
pos_DI14, neg_DI14 = [], []
dx14, next_adx14 = [], []
for i in xrange(0,len(highlowclosedf[each])):
    if i > 1:
        highlowclose     = highlowclosedf[each].iloc[i]
        prevhighlowclose = highlowclosedf[each].iloc[i-1]
        
        true_range.append(max((highlowclose['high'] - highlowclose['low']), 
                           abs(highlowclose['high'] - prevhighlowclose['close']),
                           abs(highlowclose['low']  - prevhighlowclose['close'])))
                
        plus_DM.append(highlowclose['high']     - prevhighlowclose['high'])
        minus_DM.append(prevhighlowclose['low'] - highlowclose['low'])
                
        if plus_DM[i] < 0:
            plus_DM[i] = 0
        if minus_DM[i] < 0:
            minus_DM[i] = 0
    
        if i > 12:
            if i == 13:
                first_tr14     = sum(true_range[i-13:i+1])
                first_pos_dm14 = sum(plus_DM[i-13:i+1])
                first_neg_dm14 = sum(minus_DM[i-13:i+1])
                
                pos_DI14.append((first_pos_dm14 / first_tr14) * 100)
                neg_DI14.append((first_neg_dm14 / first_tr14) * 100)
                
            else:
                next_tr14      = first_tr14     - (first_tr14     / 14) + true_range[i]
                next_pos_dm14  = first_pos_dm14 - (first_pos_dm14 / 14) + plus_DM[i]
                next_neg_dm14  = first_neg_dm14 - (first_neg_dm14 / 14) + minus_DM[i]
                
                pos_DI14.append((next_pos_dm14 / next_tr14) * 100)
                neg_DI14.append((next_neg_dm14 / next_tr14) * 100)
                
                first_tr14     = next_tr14
                first_pos_dm14 = next_pos_dm14
                first_neg_dm14 = next_neg_dm14
            
            dx14.append((pos_DI14 - neg_DI14) / (pos_DI14 + neg_DI14))
            if i > 26:
                if i == 27:
                    first_adx14 = sum(dx14[i-13:i+1])
                else:
                    next_adx14.append(((first_adx14 * 13) + dx14[i]) / 14)
                    first_adx14 = next_adx14[i]
            else:
                next_adx14.append(0)
        else:
            dx14.append(0)
            next_adx14.append(0)
    else:
        true_range.append(0)
        plus_DM.append(0)
        minus_DM.append(0)
              
#Moving Average Convergence Divergence
n, m, df      = 12, 26, closings[each]
12_sma        = (df[0:13].rolling(window=n,center=False).mean()).loc[12, 0]
26_sma        = (df[0:27].rolling(window=m,center=False).mean()).loc[26, 0]
12_multiplier = (2 / (n + 1))
26_multiplier = (2 / (m + 1))
first_12_ema  = 12_sma
first_26_ema  = 26_sma

for i in xrange(0,len(df)):  
    if i > 10:          
        each_df = df.iloc[i]
        12_ema.append((each_df['close'] - first_12_ema) * 12_multiplier + first_12_ema)
        first_12_ema = 12_ema[i]
        if i > 24:
            26_ema.append((each_df['close'] - first_26_ema) * 26_multiplier + first_26_ema)
            first_26_ema = 26_ema[i]
                
            macd.append(12_ema[i] - 26_ema[i])
        else:
            macd.append(0)
    else:
        12_ema.append(0)
        26_ema.append(0)
        macd.append(0)

#Commodity Channel Index               
constant = 0.015
for i in xrange(0,len(typical_price)):
    if i > 20:
        mean = typical_price[i-19:i+1].mean()
        for x in xrange(0,20):
            abs_val = abs(typical_price[i-x] - mean)
            sum_abs_val = sum_abs_val + abs_val
        mean_deviation = sum_abs_val / 20
        20_sma = typical_price[0:21].rolling
        cci.append((typical_price[i] - (typical_price.rolling(window=20,center=False).mean()).loc[20]) / (constant * mean_deviation))
    else:
        cci.append(0)

#Relative Strength Index               
df, n = closings[each], 14
for x in xrange(0,len(df)):
    if x == 0:
        first = df.iloc[x]
    else:
        second = df.iloc[x]
        if second != first:
            if second > first:
                uplist.append(second)
            else:
                downlist.append(second)
    up_df = pd.DataFrame(uplist)
    down_df = pd.DataFrame(downlist)
                             
14_up_sma          = (up_df[0:13].rolling(window=n,center=False).mean()).loc[12, 0]
14_down_sma        = (down_df[0:13].rolling(window=n,center=False).mean()).loc[12, 0]
14_multiplier      = (2 / (n + 1))
first_14_up_ema    = 14_up_sma
first_14_down_ema  = 14_down_sma
                
for i in xrange(0,len(up_df)):  
    if i > 12:  
        each_df = up_df.iloc[i]
        14_up_ema.append((each_df['close'] - first_14_up_ema) * 14_multiplier + first_14_up_ema)
        first_14_up_ema = 14_up_ema[i]  
    else:
        14_up_ema.append(0)
for i in xrange(0,len(down_df)):
    if i > 12:  
        each_df = down_df.iloc[i]
        14_down_ema.append((each_df['close'] - first_14_down_ema) * 14_multiplier + first_14_down_ema)
        first_14_down_ema = 14_down_ema[i]  
    else:
        14_down_ema.append(0)            

if len(14_down_ema) != len(14_up_ema):
    difference = abs(len(14_down_ema) - len(14_up_ema))
    if len(14_down_ema) > len(14_up_ema):
        u = 0
        while u < difference:
            14_up_ema.prepend(0)
            u += 1
    else:
        u = 0
        while u < difference:
            14_down_ema.prepend(0)
            u += 1  

for i in xrange(0,len(14_up_ema)):    
    rs = 14_up_ema[i] / 14_down_ema[i]
    rsi.append(100 - (100 / (1 + rs)))          
                


    Stochastic Oscillator
        1. Calculate %K, comparing latest Closing price to range traded over selected period: 
            -CL = Close [today] - Lowest Low [in %K Periods] 
            -HL = Highest High [in %K Periods] - Lowest Low [in %K Periods] 
            -%K = CL / HL *100
        2. Calculate %D by smoothing %K using 3 period simple moving average

# %%
dfd = open('combinedafter04featuredf.pickle','rb')
dfd2 = open('historicallist.pickle','rb')
feats = pickle.load(dfd)
historicals = pickle.load(dfd2)
dfd.close()
dfd2.close()
